# %%
# !pip install APIMakeSens
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from MakeSens import MakeSens
# Out:
# Requirement already satisfied: APIMakeSens in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (1.3.5)
# Requirement already satisfied: pandas in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from APIMakeSens) (2.0.3)
# Requirement already satisfied: requests in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from APIMakeSens) (2.31.0)
# Requirement already satisfied: datetime in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from APIMakeSens) (5.1)
# Requirement already satisfied: zope.interface in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from datetime->APIMakeSens) (6.0)
# Requirement already satisfied: pytz in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from datetime->APIMakeSens) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from pandas->APIMakeSens) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from pandas->APIMakeSens) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from pandas->APIMakeSens) (1.25.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from requests->APIMakeSens) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from requests->APIMakeSens) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from requests->APIMakeSens) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from requests->APIMakeSens) (2023.5.7)
# Requirement already satisfied: six>=1.5 in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->APIMakeSens) (1.16.0)
# Requirement already satisfied: setuptools in /home/juanguarin/Documentos/python-venv/lib/python3.11/site-packages (from zope.interface->datetime->APIMakeSens) (65.5.0)

# %%
fecha_inicio = "2023-08-03 00:00:00"
fecha_fin = "2023-08-17 00:00:00"
estacion = "mE1_00008"
frecuencia = "1T"
data = MakeSens.download_data(estacion, fecha_inicio, fecha_fin, frecuencia)
data
# Out:
#                       ts    humedad   humedad2  iluminancia  pm10_1  \
# 0    2023-08-03 00:00:00  37.669041  42.561989        274.0    16.0
# 1    2023-08-03 00:04:00  37.032421  41.998932        278.0    16.0
# 2    2023-08-03 00:07:00  37.374500  42.478065        279.0    14.0
# 3    2023-08-03 00:09:00  37.326153  42.368198        275.0    16.0
# 4    2023-08-03 00:11:00  37.225590  42.441444        276.0    17.0
# ...                  ...        ...        ...          ...     ...
# 7230 2023-08-16 23:49:00  39.024628  44.745556        273.0     6.0
# 7231 2023-08-16 23:51:00  39.060333  45.142292        269.0     7.0
# 7232 2023-08-16 23:53:00  39.575283  45.523766        271.0     4.0
# 7233 2023-08-16 23:56:00  38.976231  44.840160        275.0     4.0
# 7234 2023-08-16 23:58:00  40.005676  45.487144        275.0     5.0
#
#       pm10_1_AE  pm10_2  pm10_2_AE  pm1_1  pm1_1_AE  ...  pm_n_10_0_2  \
# 0          16.0    15.0       15.0   13.0      13.0  ...          0.0
# 1          16.0    16.0       16.0   11.0      11.0  ...          0.0
# 2          14.0    15.0       15.0    9.0       9.0  ...          0.0
# 3          16.0    15.0       15.0   12.0      12.0  ...          0.0
# 4          17.0    14.0       14.0   11.0      11.0  ...          1.0
# ...         ...     ...        ...    ...       ...  ...          ...
# 7230        6.0     6.0        6.0    5.0       5.0  ...          0.0
# 7231        7.0     6.0        6.0    5.0       5.0  ...          0.0
# 7232        4.0     5.0        5.0    3.0       3.0  ...          0.0
# 7233        4.0     3.0        3.0    4.0       4.0  ...          0.0
# 7234        5.0     3.0        3.0    3.0       3.0  ...          0.0
#
#       pm_n_1_0_1  pm_n_1_0_2  pm_n_2_5_1  pm_n_2_5_2  pm_n_5_0_1  pm_n_5_0_2  \
# 0           92.0       100.0         0.0        11.0         0.0         0.0
# 1           94.0        97.0         6.0         7.0         2.0         0.0
# 2           76.0        73.0         2.0         6.0         2.0         1.0
# 3           92.0        89.0         4.0         7.0         2.0         1.0
# 4           98.0        77.0         4.0         7.0         4.0         3.0
# ...          ...         ...         ...         ...         ...         ...
# 7230        34.0        29.0         0.0         5.0         0.0         0.0
# 7231        38.0        30.0         2.0         4.0         0.0         2.0
# 7232        26.0        22.0         0.0         4.0         0.0         0.0
# 7233        26.0        10.0         0.0         1.0         0.0         0.0
# 7234        16.0        16.0         2.0         1.0         2.0         0.0
#
#          presion  temperatura  temperatura2
# 0     675.398254    38.018097     37.133976
# 1     656.151489    38.465343     37.497139
# 2     666.744507    38.223728     37.216755
# 3     660.434937    38.367668     37.344929
# 4     656.289978    38.465343     37.401009
# ...          ...          ...           ...
# 7230  741.753052    36.357655     35.093842
# 7231  746.616394    36.234276     35.024414
# 7232  767.101196    35.699654     34.543755
# 7233  766.329163    35.720215     34.404900
# 7234  768.677856    35.658527     34.557106
#
# [7235 rows x 31 columns]

# %%
columnas = ["pm10_1", "pm10_2", 'ts']
pm_data = data[columnas]

pm_data = pm_data.set_index('ts')
pm_data.index = pd.to_datetime(pm_data.index)
pm_data
# Out:
#                      pm10_1  pm10_2
# ts
# 2023-08-03 00:00:00    16.0    15.0
# 2023-08-03 00:04:00    16.0    16.0
# 2023-08-03 00:07:00    14.0    15.0
# 2023-08-03 00:09:00    16.0    15.0
# 2023-08-03 00:11:00    17.0    14.0
# ...                     ...     ...
# 2023-08-16 23:49:00     6.0     6.0
# 2023-08-16 23:51:00     7.0     6.0
# 2023-08-16 23:53:00     4.0     5.0
# 2023-08-16 23:56:00     4.0     3.0
# 2023-08-16 23:58:00     5.0     3.0
#
# [7235 rows x 2 columns]

# %%
columnas = pm_data.columns
for col in columnas:
  pm_data[col] = pm_data[col].where(pm_data[col]<120, np.nan)

# %%
pm_data['mean'] = pm_data[['pm10_1','pm10_2']].mean(axis=1)    # 1ra forma
pm_data
# Out:
#                      pm10_1  pm10_2  mean
# ts
# 2023-08-03 00:00:00    16.0    15.0  15.5
# 2023-08-03 00:04:00    16.0    16.0  16.0
# 2023-08-03 00:07:00    14.0    15.0  14.5
# 2023-08-03 00:09:00    16.0    15.0  15.5
# 2023-08-03 00:11:00    17.0    14.0  15.5
# ...                     ...     ...   ...
# 2023-08-16 23:49:00     6.0     6.0   6.0
# 2023-08-16 23:51:00     7.0     6.0   6.5
# 2023-08-16 23:53:00     4.0     5.0   4.5
# 2023-08-16 23:56:00     4.0     3.0   3.5
# 2023-08-16 23:58:00     5.0     3.0   4.0
#
# [7235 rows x 3 columns]

# %%
pm_data['hora'] = pm_data.index.hour.values # Agregamos una columna "hora" al DataFrame temp que contenga la hora de cada dato
pm_data.head()
# Out:
#                      pm10_1  pm10_2  mean  hora
# ts
# 2023-08-03 00:00:00    16.0    15.0  15.5     0
# 2023-08-03 00:04:00    16.0    16.0  16.0     0
# 2023-08-03 00:07:00    14.0    15.0  14.5     0
# 2023-08-03 00:09:00    16.0    15.0  15.5     0
# 2023-08-03 00:11:00    17.0    14.0  15.5     0

# %%
pm_data_h = pm_data.groupby(pm_data['hora']).mean()
pm_data_hstd = pm_data.groupby(pm_data['hora']).std()
pm_data_h.head(24)
# Out:
#          pm10_1     pm10_2       mean
# hora
# 0     13.680272  12.935154  13.319728
# 1     15.665574  14.396721  15.031148
# 2     16.232026  14.813725  15.522876
# 3     15.096220  13.580756  14.338488
# 4     14.328767  12.893836  13.611301
# 5     12.927393  11.650165  12.288779
# 6     12.077966  10.966216  11.527027
# 7     12.327586  11.000000  11.663793
# 8     11.673981  10.507837  11.090909
# 9     12.402597  11.279221  11.840909
# 10    14.505576  13.260223  13.882900
# 11    18.396040  16.600660  17.498350
# 12    21.010239  18.672355  19.841297
# 13    16.701342  15.067114  15.884228
# 14    16.097973  14.317568  15.207770
# 15    14.824138  13.355172  14.089655
# 16    12.060000  11.010000  11.535000
# 17    10.250000   9.182099   9.716049
# 18     8.788344   7.904908   8.346626
# 19     9.015873   8.079365   8.547619
# 20     9.702532   8.920886   9.311709
# 21    10.422951   9.098361   9.760656
# 22    11.870968  10.561290  11.216129
# 23    14.559441  13.066434  13.812937

# %%
fig = plt.figure(figsize=(12, 5))
ax = fig.gca()

#Graficamos los datos
plt.bar(pm_data_h.index, pm_data_h['mean'], alpha=0.6)
plt.plot(pm_data_h['mean'], '-r',  label="pm 10 por hora", alpha=0.6)
plt.plot(pm_data_h['mean']+pm_data_hstd['mean'],  '--c', label="pm 10 + std",         alpha=0.6,lw=1.4)
plt.plot(pm_data_h['mean']-pm_data_hstd['mean'],  '--b', label="pm 10 - std",         alpha=0.6,lw=1.4)

#Coloreamos el area entre las lineas de maximo y minimo
plt.fill_between(pm_data_h['mean'].index, pm_data_h['mean']+pm_data_hstd['mean'], pm_data_h['mean']-pm_data_hstd['mean'], alpha=0.3, color="lightcoral")

#Formateamos el eje de fechas para que se vea mejor
ax.tick_params(which='major', pad=10, length=8, labelsize=12, direction="inout", width=1.5)
ax.tick_params(which='minor', length=4)
ax.set_xticks(range(0,24,5))
ax.set_xticks(range(0,24,1), minor=True)
ax.set_xticklabels(["00:00", "05:00", "10:00", "15:00", "20:00"])

#Agregamos la leyenda, los titulos y la grilla
plt.ylabel("material particulado [$\mu g/cm^3$]")
plt.xlabel("Hora")
plt.title("Material particulado en FCUIS por hora")
plt.grid(True)
plt.legend()

plt.show()

# %%
fig = plt.figure(figsize=(12, 5))
ax = fig.gca()

dates = []
for date in pm_data.index.to_pydatetime():
    dates.append( float(date.strftime('%H')) + float(date.strftime('%M'))/60 + float(date.strftime('%S'))/3600)

#Graficamos los datos
plt.plot(dates, pm_data['mean'], 'o',ms=1, alpha=0.2)
plt.plot(pm_data_h['mean'], '-r',  label="pm 10 por hora", alpha=0.6)
plt.plot(pm_data_h['mean']+pm_data_hstd['mean'],  '--c', label="pm 10 + std",         alpha=0.6,lw=1.4)
plt.plot(pm_data_h['mean']-pm_data_hstd['mean'],  '--b', label="pm 10 - std",         alpha=0.6,lw=1.4)

#Coloreamos el area entre las lineas de maximo y minimo
plt.fill_between(pm_data_h['mean'].index, pm_data_h['mean']+pm_data_hstd['mean'], pm_data_h['mean']-pm_data_hstd['mean'], alpha=0.3, color="lightcoral")

#Formateamos el eje de fechas para que se vea mejor
ax.tick_params(which='major', pad=10, length=8, labelsize=12, direction="inout", width=1.5)
ax.tick_params(which='minor', length=4)
ax.set_xticks(range(0,24,5))
ax.set_xticks(range(0,24,1), minor=True)
ax.set_xticklabels(["00:00", "05:00", "10:00", "15:00", "20:00"])

#Agregamos la leyenda, los titulos y la grilla
plt.ylabel("material particulado [$\mu g/cm^3$]")
plt.xlabel("Hora")
plt.title("Material particulado en FCUIS por hora")
plt.grid(True)
plt.legend()
plt.ylim(-0.5,40)
plt.show()

# %%
import seaborn as sns

# %%
pm_data_hmax = pm_data.groupby(pm_data['hora']).max()
pm_data_hmin = pm_data.groupby(pm_data['hora']).min()

# %%
# Generamos la figura
fig = plt.figure(figsize=(14, 6))
ax = fig.gca()

# Diagrama cajas y bigotes
sns.boxplot(data = pm_data, x='hora', y='mean', ax=ax)

# Otros graficos
plt.plot(pm_data_h['mean'],     '-ok', label="pm10 promedio", alpha=0.6)
plt.plot(pm_data_hmax['mean'], '--r', label="pm10 máximo",   alpha=0.6)
plt.plot(pm_data_hmin['mean'], '--b', label="pm10 mínimo",   alpha=0.6)

# Formateamos el eje de fechas para que se vea mejor
ax.tick_params(which='major', pad=10, length=8, labelsize=12, direction="inout", width=1.5)
ax.tick_params(which='minor', length=4)
ax.set_xticks(range(0,24,5))
ax.set_xticks(range(0,24,1), minor=True)
ax.set_xticklabels(["00:00", "05:00", "10:00", "15:00", "20:00"], fontsize=12)

# Agregamos la leyenda, los titulos y la grilla
plt.ylabel("pm10", fontsize=15)
plt.xlabel("Hora", fontsize=15)
plt.title("Gráfica de cajas y bigotes para pm10 por hora", fontsize=18)
plt.legend()
plt.grid(True)

plt.show()
