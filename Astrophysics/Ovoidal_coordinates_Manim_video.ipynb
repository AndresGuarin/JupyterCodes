# %%
from manim import *
config.media_width = "75%"
config.verbosity = "WARNING"

# %%
# %%manim -qh text_positioning
#
# class text_positioning(Scene):
#     def construct(self):
#         t = MathTex(r"\int_a^c f'(x) dx = f(c)- f(a)")
#         t.move_to([0,2,0])
#         p = Dot([0,2,0],color=YELLOW)
#         self.add(t,p)
#         grid = NumberPlane(
#             x_range=(-7,7,1),
#             y_range=(-4,4,1),
#             #x_length=7,
#             #y_length=4
#         )
#         self.add(grid)
#         #self.play(Create(grid,run_time=4,lag_ratio=0.1))
#         #self.wait(5)

# %%
# %%manim -qh CircleToSquare
#
# class IntersectaLineas(Scene):
#   def construct(self):
#     ax = Axes(x_range=[-1, 10], y_range=[-1, 10])
#
#
# class CircleToSquare(Scene):
#     def construct(self):
#         blue_circle = Circle(color=BLUE, fill_opacity=0.5)
#         green_square = Square(color=GREEN, fill_opacity=0.8)
#         self.play(Create(blue_circle))
#         self.wait()
#
#         self.play(Transform(blue_circle, green_square))
#         self.wait()
# Out:
# <video src="media\jupyter\CircleToSquare@2024-04-01@19-03-58.mp4" controls autoplay loop style="max-width: 75%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
